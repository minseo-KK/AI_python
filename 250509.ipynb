# %%
4 #데이터 정의
months=['Jan','Feb','Mar','April','May','June','July','Agust','Sep','Oct','November','December']
rainfall=['30','' ]

8 #



23 # y축 범위 설정 (0부터 시작하여 최대값보다 약간 더 높게)
plt.ylim(0,max(rainfall)*1.1)

26 # 데이터 포인트에 값 표시
for i. value in enumerate(rainfall):
    plt.text(i,value+10,str(value), ha='center',va='bottom')

30 #레이아웃 조정
plt.tight_layout()

33 #그래프 표시
plt.show()

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.2

# %%
pip install numpy

# %%
import numpy as np

a = np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[1, 2], [3, 4]])
print(b)
# Out:
# [[1 2]
#  [3 4]]

# %%
c=[1,2,3]

# %%
type(c)
# Out:
# list

# %%
arr = np.array([10, 20, 30, 40, 50])

print(arr[0])       # 첫 번째 요소
print(arr[-1])      # 마지막 요소
print(arr[1:4])     # 1~3번 인덱스 값
# Out:
# 10
# 50
# [20 30 40]

# %%
matrix = np.array([[1, 2], [3, 4], [5, 6]])

print(matrix[0, 1])      # 첫 번째 행, 두 번째 열
print(matrix[1:])        # 두 번째 행 이후 모두
# Out:
# 2
# [[3 4]
#  [5 6]]

# %%
a = np.array([1, 2, 3])
b = np.array([10, 20, 30])

print(a + b)         # [11 22 33]
print(a * b)         # [10 40 90]
print(a ** 2)        # 제곱 [1 4 9]
print(np.sqrt(a))    # 제곱근
# Out:
# [11 22 33]
# [10 40 90]
# [1 4 9]
# [1.         1.41421356 1.73205081]

# %%
arr = np.array([1, 2, 3, 4, 5])

print("Sum:", np.sum(arr))
print("Mean:", np.mean(arr))
print("Standard Deviation:", np.std(arr))
print("Min/Max:", np.min(arr), np.max(arr))
# Out:
# Sum: 15
# Mean: 3.0
# Standard Deviation: 1.4142135623730951
# Min/Max: 1 5

# %%
arr = np.array([1, 2, 3])
print(arr + 10)  # 모든 원소에 10 더하기
# Out:
# [11 12 13]

# %%
arr = np.array([10, 20, 30, 40, 50])

print(arr[arr > 30])  # 30보다 큰 요소만, 조건달기
# Out:
# [40 50]

# %%
# 실습문제 1.다음 조건에 맞는 배열을 생성하고 출력하세요.
# 1차원 배열, 5개의 요소, 0으로 초기화된 배열

import numpy as np

arr = np.zeros(5)
print(arr)
# Out:
# [0. 0. 0. 0. 0.]

# %%
# 실습문제 2.1부터 10까지의 숫자 중 짝수만 포함하는 배열을 생성하세요.

arr=np.arange(2,11,2)
print(arr)
# Out:
# [ 2  4  6  8 10]

# %%
# 실습문제 3. [2, 4, 6] 배열과 [10, 20, 30] 배열을 각각 생성하고, 곱셈 연산을 수행한 결과를 출력하세요.

a= np.array([2,4,6])
b= np.array([10,20,30])

print(a*b)
# Out:
# [ 20  80 180]

# %%
# 실습문제 4. 위 배열에서 20보다 큰 요소만 필터링해서 출력하세요.

a= np.array([2,4,6])
b= np.array([10,20,30])

result=a*b
print(a*b)

filtered=result[result>20]
print(filtered)
# Out:
# [ 20  80 180]
# [ 80 180]

# %%
#### Pandas ####

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# pandas에는 series 와 dataframe이 존재
# 주로 series를 사용

# %%
# dataframe 생성
data = {
    '이름': ['홍길동', '김철수', '이영희'],
    '나이': [25, 30, 27],
    '성별': ['남', '남', '여']
}

df = pd.DataFrame(data)
print(df)
# Out:
#     이름  나이 성별
# 0  홍길동  25  남
# 1  김철수  30  남
# 2  이영희  27  여

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/titanic.csv)
print(df.head())
# Out:
#   File "<ipython-input-57-64a1cf033992>", line 1
#     df = pd.read_csv('/titanic.csv)
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df.to_csv('/titanic.csv', index=False)

# %%
df = pd.read_csv('/titanic.csv')

result=df.groupby('Sex')['Age'].count()
print(result)
# Out:
# Sex
# 0    843
# 1    466
# Name: Age, dtype: int64

# %%
df = pd.read_csv('/titanic.csv')
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
df = pd.read_csv('/titanic.csv')
df['Age']
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#         ...
# 1304    28.0
# 1305    39.0
# 1306    38.5
# 1307    28.0
# 1308    28.0
# Name: Age, Length: 1309, dtype: float64

# %%
df = pd.read_csv('/titanic.csv')
print(df[df['Age']>30])
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# 6               7  54.0   51.8625    0      0     0       0       0       0
# 11             12  58.0   26.5500    1      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1295         1296  43.0   27.7208    0      1     0       0       0       0
# 1298         1299  50.0  211.5000    0      1     0       0       0       0
# 1302         1303  37.0   90.0000    1      1     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
#
# ...

# %%
df = pd.read_csv('/titanic.csv')
df.dropna() # 결측치: 결함이 있는 데이터 (ex.비어있는 데이터)
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
df = pd.read_csv('/titanic.csv')
result = df.groupby('Sex')['Age'].mean()
print(result)
# Out:
# Sex
# 0    30.017888
# 1    28.572082
# Name: Age, dtype: float64
